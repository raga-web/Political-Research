# %%
import import_ipynb
from Analysis import cluster_0, Analyze
# Out:
# importing Jupyter notebook from Analysis.ipynb

# %%
cluster_0.head()
# Out:
#     Constituency_Number Constituency_Name     Districts Classification  \
# 0                     1       ICHCHAPURAM    SRIKAKULAM          RURAL
# 2                     3           TEKKALI    SRIKAKULAM          RURAL
# 4                     5        SRIKAKULAM    SRIKAKULAM     SEMI_URBAN
# 12                   14           BOBBILI  VIZIANAGARAM          RURAL
# 16                   18      VIZIANAGARAM  VIZIANAGARAM          URBAN
#
#    Caste Majority 1983 1985 1989 1994 1999  VM_1999 2004  VM_2004 2009  \
# 0             OBC  TDP  TDP  TDP  TDP  TDP        0  INC        1  TDP
# 2             OBC  TDP  TDP  TDP  TDP  TDP        1  INC        2  INC
# 4             OBC  TDP  TDP  TDP  TDP  TDP        2  INC        1  INC
# 12            OBC  TDP  TDP  INC  TDP  INC        1  INC        2  INC
# 16            OBC  TDP  TDP  TDP  TDP  TDP        1  IND        0  TDP
#
#     VM_2009   2014  VM_2014   2019  VM_2019  predicted_cluster
# ...

# %%
cluster_0.describe(include='all')
# Out:
#         Constituency_Number Constituency_Name      Districts Classification  \
# count              38.00000                38             38             38
# unique                  NaN                37             10              3
# top                     NaN        PRATHIPADU  VISHAKAPATNAM          RURAL
# freq                    NaN                 2              8             22
# mean               58.50000               NaN            NaN            NaN
# std                42.08598               NaN            NaN            NaN
# min                 1.00000               NaN            NaN            NaN
# 25%                29.25000               NaN            NaN            NaN
# 50%                45.00000               NaN            NaN            NaN
# 75%                84.00000               NaN            NaN            NaN
# max               167.00000               NaN            NaN            NaN
#
# ...

# %%
# Cluster analysis
Analyze(cluster_0)
