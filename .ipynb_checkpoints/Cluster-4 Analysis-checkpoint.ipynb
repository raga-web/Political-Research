# %%
import import_ipynb
from Analysis import cluster_3, Analyze
# Out:
# importing Jupyter notebook from Analysis.ipynb

# %%
cluster_3.head()
# Out:
#     Constituency_Number Constituency_Name      Districts Classification  \
# 5                     6     AMADALAVALASA     SRIKAKULAM          RURAL
# 10                   12     PARVATHIPURAM   VIZIANAGARAM          RURAL
# 41                   46        GANNAVARAM  EAST GODAVARI          RURAL
# 43                   48         MANDAPETA  EAST GODAVARI          RURAL
# 44                   49       RAJANAGARAM  EAST GODAVARI          RURAL
#
#    Caste Majority 1983 1985 1989 1994 1999  VM_1999 2004  VM_2004 2009  \
# 5             OBC  TDP  TDP  INC  TDP  TDP        0  INC        0  INC
# 10            OBC  TDP  TDP  TDP  TDP  INC        2  INC        0  INC
# 41             SC  TDP  TDP  INC  TDP  BJP        2  INC        0  INC
# 43             FC  TDP  TDP  INC  TDP  TDP        2  INC        1  TDP
# 44             FC  TDP  TDP  INC  TDP  TDP        0  INC        0  TDP
#
#     VM_2009 2014  VM_2014   2019  VM_2019  predicted_cluster
# ...

# %%
cluster_3.describe(include='all')
# Out:
#         Constituency_Number Constituency_Name Districts Classification  \
# count             29.000000                29        29             29
# unique                  NaN                28        11              1
# top                     NaN        GANNAVARAM    GUNTUR          RURAL
# freq                    NaN                 2         6             29
# mean              92.896552               NaN       NaN            NaN
# std               45.969202               NaN       NaN            NaN
# min                6.000000               NaN       NaN            NaN
# 25%               60.000000               NaN       NaN            NaN
# 50%               88.000000               NaN       NaN            NaN
# 75%              122.000000               NaN       NaN            NaN
# max              175.000000               NaN       NaN            NaN
#
#        Caste Majority 1983 1985 1989 1994 1999    VM_1999 2004    VM_2004  \
# ...

# %%
Analyze(cluster_3)
