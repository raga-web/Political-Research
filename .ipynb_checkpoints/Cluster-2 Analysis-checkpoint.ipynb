# %%
import import_ipynb
from Analysis import cluster_1, Analyze
# Out:
# importing Jupyter notebook from Analysis.ipynb

# %%
cluster_1.head()
# Out:
#     Constituency_Number Constituency_Name      Districts Classification  \
# 15                   17        NELLIMARLA   VIZIANAGARAM          RURAL
# 52                   58       NARASAPURAM  WEST GODAVARI          RURAL
# 67                   73          KAIKALUR        KRISHNA          RURAL
# 71                   79   VIJAYAWADA WEST        KRISHNA          URBAN
# 72                   81   VIJAYAWADA EAST        KRISHNA          URBAN
#
#    Caste Majority 1983 1985 1989 1994 1999  VM_1999 2004  VM_2004  2009  \
# 15            OBC  INC  INC  INC  TDP  INC        0  INC        0   INC
# 52            OBC  INC  CPI  CPI  CPI  INC        1  INC        2   INC
# 67            OBC  INC  INC  INC  INC  IND        0  INC        0   TDP
# 71            OBC  TDP  CPI  INC  CPI  INC        0  CPI        2  PRAP
# 72            OBC  TDP  INC  INC  INC  BJP        1  INC        2  PRAP
#
#     VM_2009   2014  VM_2014   2019  VM_2019  predicted_cluster
# ...

# %%
cluster_1.describe(include='all')
# Out:
#         Constituency_Number Constituency_Name Districts Classification  \
# count             25.000000                25        25             25
# unique                  NaN                25        10              3
# top                     NaN       KAMALAPURAM   KURNOOL          RURAL
# freq                    NaN                 1         7             15
# mean             121.360000               NaN       NaN            NaN
# std               37.102201               NaN       NaN            NaN
# min               17.000000               NaN       NaN            NaN
# 25%              111.000000               NaN       NaN            NaN
# 50%              132.000000               NaN       NaN            NaN
# 75%              143.000000               NaN       NaN            NaN
# max              172.000000               NaN       NaN            NaN
#
#        Caste Majority 1983 1985 1989 1994 1999   VM_1999 2004    VM_2004 2009  \
# ...

# %%
Analyze(cluster_1)
