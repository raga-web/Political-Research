# %%
from kmodes.kmodes import KModes
import pandas as pd
import numpy as np

# %%
# suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pyplot import xticks

# %%
# reading the data
data = pd.read_csv("cluster.csv")

# %%
data.head()
# Out:
#   Constituency_Name   Districts  Constituency_Number Classification  \
# 0       ICHCHAPURAM  SRIKAKULAM                    1          RURAL
# 1            PALASA  SRIKAKULAM                    2          RURAL
# 2           TEKKALI  SRIKAKULAM                    3          RURAL
# 3       PATHAPATNAM  SRIKAKULAM                    4          RURAL
# 4        SRIKAKULAM  SRIKAKULAM                    5     SEMI_URBAN
#
#   Caste Majority 1983 1985 1989 1994 1999  VM_1999 2004  VM_2004 2009  \
# 0            OBC  TDP  TDP  TDP  TDP  TDP        0  INC        1  TDP
# 1            OBC  INC  TDP  IND  TDP  TDP        2  TDP        2  INC
# 2            OBC  TDP  TDP  TDP  TDP  TDP        1  INC        2  INC
# 3             FC  TDP  INC  TDP  TDP  TDP        2  TDP        0  INC
# 4            OBC  TDP  TDP  TDP  TDP  TDP        2  INC        1  INC
#
#    VM_2009   2014  VM_2014   2019  VM_2019
# 0        0    TDP        2    TDP        1
# 1        1    TDP        2  YSRCP        2
# 2        0    TDP        1    TDP        1
# 3        2  YSRCP        0  YSRCP        2
# 4        0    TDP        2  YSRCP        1

# %%
data.columns
# Out:
# Index(['Constituency_Name', 'Districts', 'Constituency_Number',
#        'Classification', 'Caste Majority', '1983', '1985', '1989', '1994',
#        '1999', 'VM_1999', '2004', 'VM_2004', '2009', 'VM_2009', '2014',
#        'VM_2014', '2019', 'VM_2019'],
#       dtype='object')

# %%
variable_data = data[['Districts','Classification', 'Caste Majority', '1983', '1985', '1989', '1994',
       '1999', 'VM_1999', '2004', 'VM_2004', '2009', 'VM_2009', '2014',
       'VM_2014', '2019', 'VM_2019']]

# %%
variable_data.describe(include='all')
# Out:
#             Districts Classification Caste Majority 1983 1985 1989 1994 1999  \
# count             162            162            162  162  162  162  162  162
# unique             13              3              4    4    5    6    5    4
# top     EAST GODAVARI          RURAL            OBC  TDP  TDP  INC  TDP  TDP
# freq               19            121            103  144  122  111  130  110
# mean              NaN            NaN            NaN  NaN  NaN  NaN  NaN  NaN
# std               NaN            NaN            NaN  NaN  NaN  NaN  NaN  NaN
# min               NaN            NaN            NaN  NaN  NaN  NaN  NaN  NaN
# 25%               NaN            NaN            NaN  NaN  NaN  NaN  NaN  NaN
# 50%               NaN            NaN            NaN  NaN  NaN  NaN  NaN  NaN
# 75%               NaN            NaN            NaN  NaN  NaN  NaN  NaN  NaN
# max               NaN            NaN            NaN  NaN  NaN  NaN  NaN  NaN
#
#            VM_1999 2004     VM_2004 2009     VM_2009 2014     VM_2014   2019  \
# count   162.000000  162  162.000000  162  162.000000  162  162.000000    162
# unique         NaN    7         NaN    3         NaN    5         NaN      3
# top            NaN  INC         NaN  INC         NaN  TDP         NaN  YSRCP
# freq           NaN  119         NaN   98         NaN   98         NaN    138
# mean      1.172840  NaN    1.296296  NaN    1.043210  NaN    1.259259    NaN
# std       0.838368  NaN    0.802859  NaN    0.858634  NaN    0.845562    NaN
# min       0.000000  NaN    0.000000  NaN    0.000000  NaN    0.000000    NaN
# 25%       0.000000  NaN    1.000000  NaN    0.000000  NaN    0.000000    NaN
# 50%       1.000000  NaN    2.000000  NaN    1.000000  NaN    2.000000    NaN
# 75%       2.000000  NaN    2.000000  NaN    2.000000  NaN    2.000000    NaN
# max       2.000000  NaN    2.000000  NaN    2.000000  NaN    2.000000    NaN
#
#            VM_2019
# count   162.000000
# unique         NaN
# top            NaN
# freq           NaN
# mean      1.635802
# std       0.684851
# min       0.000000
# 25%       2.000000
# 50%       2.000000
# 75%       2.000000
# max       2.000000

# %%
# maintaining copy of categorical data
import copy
training_data = copy.deepcopy(variable_data)

# %%
# adding indexed labels to data
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
variable_data = variable_data.apply(le.fit_transform)
variable_data.head()
# Out:
#    Districts  Classification  Caste Majority  1983  1985  1989  1994  1999  \
# 0          9               0               1     3     4     4     4     3
# 1          9               0               1     2     4     3     4     3
# 2          9               0               1     3     4     4     4     3
# 3          9               0               0     3     2     4     4     3
# 4          9               1               1     3     4     4     4     3
#
#    VM_1999  2004  VM_2004  2009  VM_2009  2014  VM_2014  2019  VM_2019
# 0        0     4        1     2        0     3        2     1        1
# 1        2     6        2     0        1     3        2     2        2
# 2        1     4        2     0        0     3        1     1        1
# 3        2     6        0     0        2     4        0     2        2
# 4        2     4        1     0        0     3        2     2        1

# %%
km_model = KModes(n_clusters=6,init='Huang',n_init=1,verbose=1)
km_clusters = km_model.fit_predict(variable_data)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 40, cost: 973.0
# Run 1, iteration: 2/100, moves: 13, cost: 970.0
# Run 1, iteration: 3/100, moves: 10, cost: 966.0
# Run 1, iteration: 4/100, moves: 3, cost: 966.0

# %%
# predicted clusters
km_clusters
# Out:
# array([0, 4, 0, 2, 0, 3, 5, 2, 2, 2, 3, 2, 0, 4, 4, 1, 0, 4, 0, 0, 0, 0,
#        2, 2, 0, 0, 0, 5, 0, 2, 4, 0, 4, 0, 0, 4, 4, 0, 0, 4, 4, 3, 0, 3,
#        3, 0, 4, 4, 2, 3, 2, 4, 1, 5, 3, 0, 0, 4, 3, 0, 3, 4, 0, 4, 4, 3,
#        2, 1, 0, 3, 0, 1, 1, 3, 3, 0, 4, 3, 0, 2, 3, 3, 4, 0, 0, 0, 0, 1,
#        3, 4, 4, 3, 3, 4, 3, 0, 2, 0, 0, 4, 2, 5, 1, 4, 5, 1, 1, 3, 1, 5,
#        2, 2, 3, 4, 2, 4, 4, 2, 2, 1, 1, 4, 1, 1, 1, 4, 1, 1, 2, 3, 1, 3,
#        1, 0, 1, 1, 2, 2, 5, 1, 5, 5, 5, 5, 5, 3, 3, 2, 2, 3, 0, 2, 2, 2,
#        0, 3, 4, 1, 1, 1, 2, 3], dtype=uint16)

# %%
# sizes of clusters
arr = list(km_clusters)
for i in range(6):
    size = arr.count(i)
    print("Size of cluster-" + str(i) + " = " + str(size))
# Out:
# Size of cluster-0 = 38
# Size of cluster-1 = 25
# Size of cluster-2 = 28
# Size of cluster-3 = 29
# Size of cluster-4 = 30
# Size of cluster-5 = 12

# %%
# encoding the data
variable_data = training_data.reset_index()
variable_data.head()
# Out:
#    index   Districts Classification Caste Majority 1983 1985 1989 1994 1999  \
# 0      0  SRIKAKULAM          RURAL            OBC  TDP  TDP  TDP  TDP  TDP
# 1      1  SRIKAKULAM          RURAL            OBC  INC  TDP  IND  TDP  TDP
# 2      2  SRIKAKULAM          RURAL            OBC  TDP  TDP  TDP  TDP  TDP
# 3      3  SRIKAKULAM          RURAL             FC  TDP  INC  TDP  TDP  TDP
# 4      4  SRIKAKULAM     SEMI_URBAN            OBC  TDP  TDP  TDP  TDP  TDP
#
#    VM_1999 2004  VM_2004 2009  VM_2009   2014  VM_2014   2019  VM_2019
# 0        0  INC        1  TDP        0    TDP        2    TDP        1
# 1        2  TDP        2  INC        1    TDP        2  YSRCP        2
# 2        1  INC        2  INC        0    TDP        1    TDP        1
# 3        2  TDP        0  INC        2  YSRCP        0  YSRCP        2
# 4        2  INC        1  INC        0    TDP        2  YSRCP        1

# %%
# combining the data
clusters_data = pd.DataFrame(km_clusters)
clusters_data.columns = ['predicted_cluster']
combined_data = pd.concat([variable_data, clusters_data],axis=1).reset_index()
combined_data = combined_data.drop(['index','level_0'],axis=1)

# %%
labels = data[['Constituency_Number','Constituency_Name']]
combined_data_with_labels = pd.concat([labels,combined_data],axis=1).reset_index()
combined_data_with_labels = combined_data_with_labels.drop(['index'],axis=1)
combined_data_with_labels.head()
# Out:
#    Constituency_Number Constituency_Name   Districts Classification  \
# 0                    1       ICHCHAPURAM  SRIKAKULAM          RURAL
# 1                    2            PALASA  SRIKAKULAM          RURAL
# 2                    3           TEKKALI  SRIKAKULAM          RURAL
# 3                    4       PATHAPATNAM  SRIKAKULAM          RURAL
# 4                    5        SRIKAKULAM  SRIKAKULAM     SEMI_URBAN
#
#   Caste Majority 1983 1985 1989 1994 1999  VM_1999 2004  VM_2004 2009  \
# 0            OBC  TDP  TDP  TDP  TDP  TDP        0  INC        1  TDP
# 1            OBC  INC  TDP  IND  TDP  TDP        2  TDP        2  INC
# 2            OBC  TDP  TDP  TDP  TDP  TDP        1  INC        2  INC
# 3             FC  TDP  INC  TDP  TDP  TDP        2  TDP        0  INC
# 4            OBC  TDP  TDP  TDP  TDP  TDP        2  INC        1  INC
#
#    VM_2009   2014  VM_2014   2019  VM_2019  predicted_cluster
# 0        0    TDP        2    TDP        1                  0
# 1        1    TDP        2  YSRCP        2                  4
# 2        0    TDP        1    TDP        1                  0
# 3        2  YSRCP        0  YSRCP        2                  2
# 4        0    TDP        2  YSRCP        1                  0

# %%
combined_data_with_labels.to_csv(r'C:/Users/rimco/Desktop/VoxPopuliR/Clustering/clustered.csv',index=False)
# Out:
# 'Constituency_Number,Constituency_Name,Districts,Classification,Caste Majority,1983,1985,1989,1994,1999,VM_1999,2004,VM_2004,2009,VM_2009,2014,VM_2014,2019,VM_2019,predicted_cluster\r\n1,ICHCHAPURAM,SRIKAKULAM,RURAL,OBC,TDP,TDP,TDP,TDP,TDP,0,INC,1,TDP,0,TDP,2,TDP,1,0\r\n2,PALASA,SRIKAKULAM,RURAL,OBC,INC,TDP,IND,TDP,TDP,2,TDP,2,INC,1,TDP,2,YSRCP,2,4\r\n3,TEKKALI,SRIKAKULAM,RURAL,OBC,TDP,TDP,TDP,TDP,TDP,1,INC,2,INC,0,TDP,1,TDP,1,0\r\n4,PATHAPATNAM,SRIKAKULAM,RURAL,FC,TDP,INC,TDP,TDP,TDP,2,TDP,0,INC,2,YSRCP,0,YSRCP,2,2\r\n5,SRIKAKULAM,SRIKAKULAM,SEMI_URBAN,OBC,TDP,TDP,TDP,TDP,TDP,2,INC,1,INC,0,TDP,2,YSRCP,1,0\r\n6,AMADALAVALASA,SRIKAKULAM,RURAL,OBC,TDP,TDP,INC,TDP,TDP,0,INC,0,INC,2,TDP,1,YSRCP,2,3\r\n7,ETCHERLA,SRIKAKULAM,RURAL,OBC,TDP,TDP,TDP,TDP,TDP,2,INC,1,INC,2,TDP,0,YSRCP,2,5\r\n8,NARASANNAPETA,SRIKAKULAM,RURAL,OBC,TDP,TDP,INC,TDP,INC,1,INC,1,INC,2,TDP,0,YSRCP,2,2\r\n10,PALAKONDA,SRIKAKULAM,RURAL,FC,TDP,TDP,INC,TDP,IND,0,TDP,2,INC,2,YSRCP,0,YSRCP,2,2\r\n11,KURUPAM,VIZIANAGARAM,RURAL,OBC,INC,INC,INC,TDP,INC,1,CPM,1,INC,2,YSRCP,2,YSRCP,2,2\r\n12,PARVATHIPURAM,VIZIANAGARAM,RURAL,OBC,TDP,TDP,TDP,TDP,INC,2,INC,0,INC,0,TDP,1,YSRCP,2,3\r\n13,SALUR,VIZIANAGARAM,RURAL,OBC,TDP,TDP,INC,TDP,TDP,2,TDP,0,INC,0,YSRCP,0,YSRCP,2,2\r\n14,BOBBILI,VIZIANAGARAM,RURAL,OBC,TDP,TDP,INC,TDP,INC,1,INC,2,INC,2,YSRCP,1,YSRCP,1,0\r\n15,CHEEPURUPALLE,VIZIANAGARAM,RURAL,OBC,TDP,TDP,TDP,TDP,TDP,0,INC,2,INC,1,TDP,2,YSRCP,2,4\r\n16,GAJAPATHINAGARAM,VIZIANAGARAM,RURAL,OBC,TDP,INC,TDP,TDP,INC,0,TDP,2,INC,2,TDP,2,YSRCP,2,4\r\n17,NELLIMARLA,VIZIANAGARAM,RURAL,OBC,INC,INC,INC,TDP,INC,0,INC,0,INC,0,TDP,1,YSRCP,2,1\r\n18,VIZIANAGARAM,VIZIANAGARAM,URBAN,OBC,TDP,TDP,TDP,TDP,TDP,1,IND,0,TDP,0,TDP,2,YSRCP,1,0\r\n19,SRUNGAVARAPUKOTA,VIZIANAGARAM,RURAL,OBC,TDP,TDP,TDP,TDP,TDP,0,INC,1,TDP,0,TDP,2,YSRCP,2,4\r\n20,BHIMILI,VISHAKAPATNAM,RURAL,OBC,TDP,TDP,TDP,TDP,TDP,2,INC,0,PRAP,1,TDP,2,YSRCP,1,0\r\n22,VISAKHAPATNAM SOUTH,VISHAKAPATNAM,URBAN,OBC,TDP,TDP,INC,TDP,BJP,1,INC,2,INC,0,TDP,2,TDP,0,0\r\n24,VISAKHAPATNAM WEST,VISHAKAPATNAM,URBAN,OBC,TDP,TDP,INC,TDP,TDP,2,INC,2,INC,0,TDP,2,TDP,2,0\r\n25,GAJUWAKA,VISHAKAPATNAM,URBAN,OBC,TDP,TDP,TDP,TDP,TDP,2,INC,2,PRAP,2,TDP,2,YSRCP,2,0\r\n26,CHODAVARAM,VISHAKAPATNAM,RURAL,FC,TDP,TDP,INC,TDP,INC,1,TDP,1,TDP,0,TDP,0,YSRCP,2,2\r\n27,MADUGULA,VISHAKAPATNAM,RURAL,OBC,TDP,TDP,TDP,TDP,TDP,1,INC,1,TDP,1,YSRCP,0,YSRCP,2,2\r\n29,PADERU,VISHAKAPATNAM,RURAL,ST,INC,TDP,INC,TDP,TDP,0,BSP,1,INC,0,YSRCP,2,YSRCP,2,0\r\n30,ANAKAPALLE,VISHAKAPATNAM,RURAL,FC,TDP,TDP,TDP,TDP,TDP,0,INC,2,PRAP,2,TDP,2,YSRCP,1,0\r\n31,PENDURTHI,VISHAKAPATNAM,RURAL,OBC,TDP,TDP,INC,CPI,TDP,2,INC,2,PRAP,0,TDP,2,YSRCP,2,0\r\n32,YELAMANCHILI,VISHAKAPATNAM,RURAL,OBC,TDP,TDP,TDP,TDP,TDP,1,INC,1,INC,2,TDP,1,YSRCP,0,5\r\n33,PAYAKARAOPET,VISHAKAPATNAM,RURAL,OBC,TDP,TDP,TDP,TDP,TDP,1,TDP,2,INC,0,TDP,0,YSRCP,2,0\r\n34,NARSIPATNAM,VISHAKAPATNAM,RURAL,OBC,TDP,TDP,INC,TDP,TDP,1,TDP,2,INC,1,TDP,0,YSRCP,2,2\r\n35,TUNI,EAST GODAVARI,RURAL,OBC,TDP,TDP,TDP,TDP,TDP,0,TDP,0,INC,1,YSRCP,2,YSRCP,2,4\r\n36,PRATHIPADU,EAST GODAVARI,RURAL,OBC,TDP,TDP,INC,TDP,TDP,2,INC,2,TDP,0,YSRCP,0,YSRCP,0,0\r\n37,PITHAPURAM,EAST GODAVARI,RURAL,OBC,TDP,TDP,INC,TDP,IND,0,BJP,2,PRAP,0,IND,2,YSRCP,2,4\r\n38,KAKINADA RURAL,EAST GODAVARI,SEMI_URBAN,OBC,TDP,TDP,INC,TDP,TDP,2,INC,2,PRAP,1,TDP,1,YSRCP,1,0\r\n39,PEDDAPURAM,EAST GODAVARI,SEMI_URBAN,FC,TDP,TDP,INC,TDP,TDP,1,INC,2,PRAP,0,TDP,2,TDP,0,0\r\n40,ANAPARTHY,EAST GODAVARI,RURAL,FC,TDP,TDP,INC,TDP,TDP,0,INC,2,INC,2,TDP,0,YSRCP,2,4\r\n41,KAKINADA CITY,EAST GODAVARI,URBAN,FC,TDP,TDP,INC,TDP,TDP,0,INC,2,INC,1,TDP,2,YSRCP,2,4\r\n42,RAMACHANDRAPURAM,EAST GODAVARI,RURAL,OBC,TDP,TDP,INC,IND,TDP,2,IND,1,INC,0,TDP,2,YSRCP,1,0\r\n43,MUMMIDIVARAM,EAST GODAVARI,RURAL,OBC,TDP,TDP,INC,INC,TDP,2,INC,2,INC,0,TDP,2,YSRCP,1,0\r\n44,AMALAPURAM,EAST GODAVARI,RURAL,OBC,TDP,INC,INC,TDP,TDP,2,IND,0,INC,1,TDP,2,YSRCP,2,4\r\n45,RAZOLE,EAST GODAVARI,RURAL,SC,TDP,TDP,INC,TDP,TDP,0,INC,2,INC,1,TDP,0,JSP,0,4\r\n46,GANNAVARAM,EAST GODAVARI,RURAL,SC,TDP,TDP,INC,TDP,BJP,2,INC,0,INC,2,TDP,1,YSRCP,2,3\r ...
