# %%
import import_ipynb
from Analysis import cluster_4, Analyze

# %%
cluster_4.head()
# Out:
#     Constituency_Number Constituency_Name      Districts Classification  \
# 1                     2            PALASA     SRIKAKULAM          RURAL
# 13                   15     CHEEPURUPALLE   VIZIANAGARAM          RURAL
# 14                   16  GAJAPATHINAGARAM   VIZIANAGARAM          RURAL
# 17                   19  SRUNGAVARAPUKOTA   VIZIANAGARAM          RURAL
# 30                   35              TUNI  EAST GODAVARI          RURAL
#
#    Caste Majority 1983 1985 1989 1994 1999  VM_1999 2004  VM_2004 2009  \
# 1             OBC  INC  TDP  IND  TDP  TDP        2  TDP        2  INC
# 13            OBC  TDP  TDP  TDP  TDP  TDP        0  INC        2  INC
# 14            OBC  TDP  INC  TDP  TDP  INC        0  TDP        2  INC
# 17            OBC  TDP  TDP  TDP  TDP  TDP        0  INC        1  TDP
# 30            OBC  TDP  TDP  TDP  TDP  TDP        0  TDP        0  INC
#
#     VM_2009   2014  VM_2014   2019  VM_2019  predicted_cluster
# ...

# %%
cluster_4.describe(include='all')
# Out:
#         Constituency_Number Constituency_Name      Districts Classification  \
# count             30.000000                30             30             30
# unique                  NaN                30             11              3
# top                     NaN         UDAYAGIRI  EAST GODAVARI          RURAL
# freq                    NaN                 1              8             24
# mean              74.100000               NaN            NaN            NaN
# std               42.368132               NaN            NaN            NaN
# min                2.000000               NaN            NaN            NaN
# 25%               41.750000               NaN            NaN            NaN
# 50%               68.000000               NaN            NaN            NaN
# 75%              106.250000               NaN            NaN            NaN
# max              169.000000               NaN            NaN            NaN
#
# ...

# %%
Analyze(cluster_4)
