# %%
import import_ipynb
from Analysis import cluster_5, Analyze
# Out:
# importing Jupyter notebook from Analysis.ipynb

# %%
cluster_5.head()
# Out:
#      Constituency_Number Constituency_Name      Districts Classification  \
# 6                      7          ETCHERLA     SRIKAKULAM          RURAL
# 27                    32      YELAMANCHILI  VISHAKAPATNAM          RURAL
# 53                    59        BHIMAVARAM  WEST GODAVARI     SEMI_URBAN
# 101                  110           KONDAPI       PRAKASAM          RURAL
# 104                  113          KANIGIRI       PRAKASAM          RURAL
#
#     Caste Majority 1983 1985 1989 1994 1999  VM_1999 2004  VM_2004 2009  \
# 6              OBC  TDP  TDP  TDP  TDP  TDP        2  INC        1  INC
# 27             OBC  TDP  TDP  TDP  TDP  TDP        1  INC        1  INC
# 53              FC  TDP  TDP  INC  TDP  TDP        2  INC        1  INC
# 101             FC  TDP  INC  INC  TDP  TDP        2  INC        1  INC
# 104             FC  TDP  TDP  INC  TDP  INC        1  INC        1  INC
#
#      VM_2009 2014  VM_2014   2019  VM_2019  predicted_cluster
# ...

# %%
cluster_5.describe(include='all')
# Out:
#         Constituency_Number Constituency_Name  Districts Classification  \
# count             12.000000                12         12             12
# unique                  NaN                12          6              3
# top                     NaN          KANIGIRI  ANANTAPUR          RURAL
# freq                    NaN                 1          6              8
# mean             113.500000               NaN        NaN            NaN
# std               52.838519               NaN        NaN            NaN
# min                7.000000               NaN        NaN            NaN
# 25%               97.250000               NaN        NaN            NaN
# 50%              134.500000               NaN        NaN            NaN
# 75%              153.250000               NaN        NaN            NaN
# max              157.000000               NaN        NaN            NaN
#
#        Caste Majority 1983 1985 1989 1994 1999    VM_1999 2004    VM_2004  \
# ...

# %%
Analyze(cluster_5)
