# %%
import import_ipynb
from Analysis import cluster_2, Analyze
# Out:
# importing Jupyter notebook from Analysis.ipynb

# %%
cluster_2.head()
# Out:
#     Constituency_Number Constituency_Name     Districts Classification  \
# 3                     4       PATHAPATNAM    SRIKAKULAM          RURAL
# 7                     8     NARASANNAPETA    SRIKAKULAM          RURAL
# 8                    10         PALAKONDA    SRIKAKULAM          RURAL
# 9                    11           KURUPAM  VIZIANAGARAM          RURAL
# 11                   13             SALUR  VIZIANAGARAM          RURAL
#
#    Caste Majority 1983 1985 1989 1994 1999  VM_1999 2004  VM_2004 2009  \
# 3              FC  TDP  INC  TDP  TDP  TDP        2  TDP        0  INC
# 7             OBC  TDP  TDP  INC  TDP  INC        1  INC        1  INC
# 8              FC  TDP  TDP  INC  TDP  IND        0  TDP        2  INC
# 9             OBC  INC  INC  INC  TDP  INC        1  CPM        1  INC
# 11            OBC  TDP  TDP  INC  TDP  TDP        2  TDP        0  INC
#
#     VM_2009   2014  VM_2014   2019  VM_2019  predicted_cluster
# ...

# %%
cluster_2.describe(include='all')
# Out:
#         Constituency_Number Constituency_Name Districts Classification  \
# count             28.000000                28        28             28
# unique                  NaN                28        13              2
# top                     NaN          RAYADURG  CHITTOOR          RURAL
# freq                    NaN                 1         4             23
# mean              95.035714               NaN       NaN            NaN
# std               59.496332               NaN       NaN            NaN
# min                4.000000               NaN       NaN            NaN
# 25%               32.250000               NaN       NaN            NaN
# 50%              114.500000               NaN       NaN            NaN
# 75%              148.250000               NaN       NaN            NaN
# max              174.000000               NaN       NaN            NaN
#
#        Caste Majority 1983 1985 1989 1994 1999    VM_1999 2004    VM_2004  \
# ...

# %%
Analyze(cluster_2)
